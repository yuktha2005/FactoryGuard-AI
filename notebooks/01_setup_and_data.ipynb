# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['Colab Notebooks',
#  'FactoryGuard_AI',
#  'Resume_Yuktha.pdf.pdf',
#  'yuktha',
#  'Classroom',
#  ' AR-Based Eye Health & Screen Time App .gform',
#  'Placement_prep',
#  'Resume-Yuktha-s (1).pdf',
#  'Resume-Yuktha-s.pdf',
#  'Copy of Ozibook - Intern recruitment drive - Oct  2025.gdoc',
#  'Docker',
#  'Resume',
#  'Yuktha S-OfferLetter (1).pdf',
#  'Receipt pay_RuAlBkcKjIGmku from PITABAS PRADHAN (Paid).pdf.pdf']

# %%
BASE_PATH = '/content/drive/MyDrive/FactoryGuard_AI'
os.listdir(BASE_PATH)
# Out:
# ['data', 'notebooks', 'models', 'src']

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
# ' AR-Based Eye Health & Screen Time App .gform'
#  Classroom
# 'Colab Notebooks'
# 'Copy of Ozibook - Intern recruitment drive - Oct  2025.gdoc'
#  Docker
#  FactoryGuard_AI
#  Placement_prep
# 'Receipt pay_RuAlBkcKjIGmku from PITABAS PRADHAN (Paid).pdf.pdf'
#  Resume
#  Resume_Yuktha.pdf.pdf
# 'Resume-Yuktha-s (1).pdf'
#  Resume-Yuktha-s.pdf
#  yuktha
# 'Yuktha S-OfferLetter (1).pdf'

# %%
# %cd FactoryGuard_AI
# Out:
# /content/drive/MyDrive/FactoryGuard_AI

# %%
# !ls
# Out:
# data  models  notebooks  src

# %%
# !git init
# !git config --global user.email "yukthaa2005.com"
# !git config --global user.name "https://github.com/yuktha2005"
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/FactoryGuard_AI/.git/

# %%
# !git branch -M main

# %%
# !find /content/drive/MyDrive/FactoryGuard_AI -name "*.ipynb"
# Out:
# /content/drive/MyDrive/FactoryGuard_AI/notebooks/01_setup_and_data.ipynb
# /content/drive/MyDrive/FactoryGuard_AI/notebooks/02_data_engineering.ipynb

# %%
# %cd /content/drive/MyDrive/FactoryGuard_AI
# !ls
# Out:
# /content/drive/MyDrive/FactoryGuard_AI
# data  models  notebooks  src

# %%
# !ls
# Out:
# data  models  notebooks  src
